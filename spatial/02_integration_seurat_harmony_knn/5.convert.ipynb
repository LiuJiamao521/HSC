# %% [markdown]
# # Convert the cellbin dataset with cell-type annotations to h5ad format

# %%
library(dplyr)
library(ggplot2)
library(Seurat)
library(patchwork)
library(randomcoloR)
set.seed(1)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching SeuratObject
#
# ‘SeuratObject’ was built under R 4.3.1 but the current version is
# 4.3.2; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# Seurat v4 was just loaded with SeuratObject v5; disabling v5 assays and
# validation routines, and ensuring assays work in strict v3/v4
# compatibility mode
#
# Warning message:
# “package ‘patchwork’ was built under R version 4.3.3”

# %%
#--------------------------spatial data
rna = readRDS("/cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/P3/ST/integration/GW16/1.GW16_obj_annote_bin30.rds")
rna@meta.data$cell_type <- rna@meta.data$cell_name

source('/cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/Sceasy/sceasy.R', chdir = TRUE)
convert_seurat_to_anndata(rna, "/cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/P3/ST/integration/GW16/1.GW16_obj_annote_bin30.h5ad")
