# %%
import subprocess as sb
BEDTOOLS_SHUFFLE = '/cluster2/huanglab/jiamao/Apps/bedtools2/bin/bedtools shuffle '
CREs_bed = '/cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/P3/ATAC/Homer/HSC/enhancer.bed'
genome = '/cluster2/huanglab/jiamao/Apps/bedtools2/genomes/human.hg38.genome'
shuffle_bed = '/cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/P3/ATAC/Homer/HSC/shuffle.bed'
cmd = BEDTOOLS_SHUFFLE+ '-i ' + CREs_bed + ' -g ' + genome + ' > '  + shuffle_bed
cmd
# Out:
# '/cluster2/huanglab/jiamao/Apps/bedtools2/bin/bedtools shuffle -i /cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/P3/ATAC/Homer/HSC/enhancer.bed -g /cluster2/huanglab/jiamao/Apps/bedtools2/genomes/human.hg38.genome > /cluster2/huanglab/jiamao/Project/HumanSpinalCord/Work/P3/ATAC/Homer/HSC/shuffle.bed'

# %%
sb.call(cmd, shell=True)
# Out:
# 0
